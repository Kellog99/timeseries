# %%
import yfinance as yf
import matplotlib.pyplot as plt

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
x= np.random.normal(0.5, 2, 1000)

# %%
height, bins, _ = plt.hist(x, bins=100, density= True)

# %%
bins
# Out:
# array([-5.64864361, -5.51323189, -5.37782016, -5.24240844, -5.10699672,
#        -4.971585  , -4.83617327, -4.70076155, -4.56534983, -4.42993811,
#        -4.29452638, -4.15911466, -4.02370294, -3.88829121, -3.75287949,
#        -3.61746777, -3.48205605, -3.34664432, -3.2112326 , -3.07582088,
#        -2.94040916, -2.80499743, -2.66958571, -2.53417399, -2.39876227,
#        -2.26335054, -2.12793882, -1.9925271 , -1.85711538, -1.72170365,
#        -1.58629193, -1.45088021, -1.31546849, -1.18005676, -1.04464504,
#        -0.90923332, -0.7738216 , -0.63840987, -0.50299815, -0.36758643,
#        -0.23217471, -0.09676298,  0.03864874,  0.17406046,  0.30947219,
#         0.44488391,  0.58029563,  0.71570735,  0.85111908,  0.9865308 ,
#         1.12194252,  1.25735424,  1.39276597,  1.52817769,  1.66358941,
#         1.79900113,  1.93441286,  2.06982458,  2.2052363 ,  2.34064802,
#         2.47605975,  2.61147147,  2.74688319,  2.88229491,  3.01770664,
# ...

# %%
meta = yf.Ticker("META")
data = meta.history(period="max")
data.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2012-05-18 00:00:00-04:00  41.758311  44.687848  37.736405  37.964809
# 2012-05-21 00:00:00-04:00  36.276591  36.405691  32.771080  33.793934
# 2012-05-22 00:00:00-04:00  32.383788  33.356990  30.725373  30.784956
# 2012-05-23 00:00:00-04:00  31.152392  32.274552  31.142461  31.778021
# 2012-05-24 00:00:00-04:00  32.721430  32.979624  31.549615  32.800873
#
#                               Volume  Dividends  Stock Splits
# Date
# 2012-05-18 00:00:00-04:00  573576400        0.0           0.0
# 2012-05-21 00:00:00-04:00  168192700        0.0           0.0
# 2012-05-22 00:00:00-04:00  101786600        0.0           0.0
# 2012-05-23 00:00:00-04:00   73600000        0.0           0.0
# 2012-05-24 00:00:00-04:00   50237200        0.0           0.0

# %%
d = yf.download("META")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.to_csv("./tmp.csv")

# %%
data.Date = data.Date.apply(lambda x: x.strftime('%Y-%m-%d'))

# %%
data
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
from pandas import Timestamp
first = data[["Date", "Open", "High"]].values[0]
first
# Out:
# array([Timestamp('2012-05-18 00:00:00-0400', tz='America/New_York'),
#        41.75830671613622, 44.687843907734816], dtype=object)

# %%
first[0].strftime('%Y-%m-%d')
# Out:
# '2012-05-18'

# %%
tickers = [
    "NVDA", "AAPL", "MSFT", "AMZN", "GOOGL", 
    "GOOG", "META", "AVGO", "TSLA", "BRK.B", 
    "LLY", "WMT", "JPM", "V", "ORCL", 
    "MA", "XOM", "JNJ", "PLTR", "ABBV", 
    "BAC", "NFLX", "COST", "AMD", "HD", 
    "PG", "MU", "GE", "CSCO", "CVX"
]
for t in tickers:
    tmp = yf.Ticker(t)
    print("################################")
    if "longBusinessSummary" not in tmp.info:
        print("azione = ", t)
# Out:
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# azione =  BRK.B
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ################################
# ...

# %%
data.to_dict(orient='records').apply(lambda x: x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 data.to_dict(orient='records').apply(lambda x: x)
#
# AttributeError: 'list' object has no attribute 'apply'

# %%
yf.Ticker()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 yf.Ticker()
#
# TypeError: Ticker.__init__() missing 1 required positional argument: 'ticker'

# %%
plt.plot(data["High"])
plt.plot(data["Open"])
plt.plot(data["Low"])
plt.plot(data["Volume"]/700000)
plt.show()
